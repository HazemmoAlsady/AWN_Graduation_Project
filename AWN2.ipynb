# %% [markdown]
# <a href="https://colab.research.google.com/github/HazemmoAlsady/AWN_Graduation_Project/blob/main/AWN2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import re
import os

# %%
df = pd.read_excel("/content/awn_dataset.xlsx")

# %%
df
# Out:
#                     name   national_id   case_type  family_size         phone  \
# 0        نجلاء عبدالباسط  5.037050e+13   ذوي إعاقة          3.0  1.183630e+09
# 1               حسن كمال  6.515039e+13       أيتام          4.0  1.014614e+09
# 2        فاطمة عبدالرحمن  3.251524e+13       أرملة          8.0  1.013125e+09
# 3        إبراهيم الهواري  4.607155e+13       أيتام          6.0  1.200902e+09
# 4                    NaN  6.335249e+13  أسرة فقيرة          7.0  1.529047e+09
# ...                  ...           ...         ...          ...           ...
# 59995      علي عبدالرحمن  2.959917e+10       أيتام          3.0  1.129841e+09
# 59996     خالد عبدالباقي  9.592012e+13       أيتام          7.0  1.226111e+09
# 59997          صفاء شريف  2.894880e+13   ذوي إعاقة          3.0  1.066819e+09
# 59998  إبراهيم عبدالفتاح  9.227969e+13         NaN          7.0  1.122038e+09
# 59999       سعاد عبدالله  4.817170e+13  أسرة فقيرة          3.0  1.062222e+09
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ...  \
# 0      سكن لدى الأقارب  ...
# 1                تمليك  ...
# 2      سكن لدى الأقارب  ...
# 3                تمليك  ...
# 4                تمليك  ...
# ...                ...  ...
# 59995       سكن عشوائي  ...
# 59996            إيجار  ...
# 59997       سكن عشوائي  ...
# 59998            إيجار  ...
# 59999            تمليك  ...
#
#                                             request_text  \
# 0      نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1      حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2      فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3      إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4      آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# ...                                                  ...
# 59995  علي عبدالرحمن من أيتام مقيم في مدينة نصر ويحتا...
# 59996  خالد عبدالباقي من أيتام مقيم في فيصل ويحتاج: ت...
# 59997  صفاء شريف من ذوي إعاقة مقيم في إمبابة ويحتاج: ...
# 59998  إبراهيم عبدالفتاح من أرملة مقيم في السيدة زينب...
# 59999  سعاد عبدالله من أسرة فقيرة مقيم في شبرا ويحتاج...
#
#             assistance_type need_level        city neighborhood  \
# 0      disability_equipment        Low    الزقازيق       إمبابة
# 1                      food       High       سوهاج        الهرم
# 2                 education        Low      الجيزة     العطارين
# 3                 financial     Medium  الإسكندرية        الهرم
# 4                      food       High    الزقازيق  السيدة زينب
# ...                     ...        ...         ...          ...
# 59995             financial     Medium       أسوان  السيدة زينب
# 59996                  food     Medium    بني سويف  سان ستيفانو
# 59997  disability_equipment     Medium         قنا    مدينة نصر
# 59998                  food        Low       أسوان         شبرا
# 59999                  food       High     القاهرة        الهرم
#
#       number_of_children   age  expense_to_income_ratio  \
# 0                    1.0  49.0                     1.70
# 1                    0.0  37.0                     1.81
# 2                    3.0  22.0                     1.55
# 3                    1.0  47.0                     1.92
# 4                    3.0  64.0                     2.00
# ...                  ...   ...                      ...
# 59995                3.0  22.0                     1.54
# 59996                4.0  46.0                      NaN
# 59997                NaN  28.0                     2.03
# 59998                2.0   NaN                     1.31
# 59999                3.0  52.0                     1.94
#
#                recommended_org  gender
# 0               جمعية الأورمان  female
# 1      جمعية التكافل الاجتماعي    male
# 2                  جمعية رسالة  female
# 3                          NaN     NaN
# 4               جمعية الأورمان  female
# ...                        ...     ...
# 59995  جمعية التكافل الاجتماعي    male
# 59996                      NaN    male
# 59997          مؤسسة مصر الخير  female
# 59998              جمعية رسالة  female
# 59999              جمعية رسالة  female
#
# [60000 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     57035 non-null  object
#  1   national_id              57050 non-null  float64
#  2   case_type                56933 non-null  object
#  3   family_size              57021 non-null  float64
#  4   phone                    57124 non-null  float64
#  5   amount_received          57009 non-null  float64
#  6   income_monthly           57073 non-null  float64
#  7   monthly_expenses         57060 non-null  float64
#  8   debts                    57014 non-null  float64
#  9   housing_type             56982 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      57007 non-null  float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 9.6+ MB

# %%
df.describe()
# Out:
#         national_id   family_size         phone  amount_received  \
# count  5.705000e+04  57021.000000  5.712400e+04     57009.000000
# mean   5.001443e+13      4.988092  1.249888e+09       764.477539
# std    2.886877e+13      1.992801  1.894823e+08       608.071375
# min    3.494987e+09      2.000000  1.000002e+09         0.000000
# 25%    2.499512e+13      3.000000  1.100078e+09       300.000000
# 50%    5.002805e+13      5.000000  1.199475e+09       600.000000
# 75%    7.521308e+13      7.000000  1.500043e+09      1000.000000
# max    9.999981e+13      8.000000  1.600000e+09      2000.000000
#
#        income_monthly  monthly_expenses         debts  number_of_children  \
# count    57073.000000      57060.000000  57014.000000        56954.000000
# mean      2497.945491       4617.924290   4777.104974            2.500193
# std        699.314027       1612.918813   6656.243027            2.056454
# min        600.000000        726.000000      0.000000            0.000000
# 25%       2027.000000       3460.000000      0.000000            1.000000
# 50%       2499.000000       4469.500000     35.000000            2.000000
# 75%       2968.000000       5632.000000   8759.750000            4.000000
# max       5792.000000      11769.000000  29998.000000            8.000000
#
#                 age  expense_to_income_ratio
# count  57007.000000             57127.000000
# mean      43.528233                 1.847942
# std       12.756803                 0.374571
# min       20.000000                 1.200000
# 25%       33.000000                 1.520000
# 50%       44.000000                 1.850000
# 75%       54.000000                 2.170000
# max       65.000000                 2.500000

# %%
raw_df = df.copy()

# %%
def clean_string_col(col):
    return (
        col.astype(str)
           .str.strip()
           .str.replace(r"\.0$", "", regex=True)
           .str.replace(r"[^\w\s\-\+\/\.]", "", regex=True)
    )

# %%
for col in ["national_id", "phone"]:
    if col in df.columns:
        df[col] = clean_string_col(df[col])

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي إعاقة          3.0  1183629898
# 1               حسن كمال  65150394917789       أيتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       أرملة          8.0  1013124808
# 3        إبراهيم الهواري  46071550347522       أيتام          6.0  1200902016
# 4                    NaN  63352487361031  أسرة فقيرة          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن     29599172910       أيتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       أيتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي إعاقة          3.0  1066819332
# 59998  إبراهيم عبدالفتاح  92279688670624         NaN          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  أسرة فقيرة          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ...  \
# 0      سكن لدى الأقارب  ...
# 1                تمليك  ...
# 2      سكن لدى الأقارب  ...
# 3                تمليك  ...
# 4                تمليك  ...
# ...                ...  ...
# 59995       سكن عشوائي  ...
# 59996            إيجار  ...
# 59997       سكن عشوائي  ...
# 59998            إيجار  ...
# 59999            تمليك  ...
#
#                                             request_text  \
# 0      نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1      حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2      فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3      إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4      آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# ...                                                  ...
# 59995  علي عبدالرحمن من أيتام مقيم في مدينة نصر ويحتا...
# 59996  خالد عبدالباقي من أيتام مقيم في فيصل ويحتاج: ت...
# 59997  صفاء شريف من ذوي إعاقة مقيم في إمبابة ويحتاج: ...
# 59998  إبراهيم عبدالفتاح من أرملة مقيم في السيدة زينب...
# 59999  سعاد عبدالله من أسرة فقيرة مقيم في شبرا ويحتاج...
#
#             assistance_type need_level        city neighborhood  \
# 0      disability_equipment        Low    الزقازيق       إمبابة
# 1                      food       High       سوهاج        الهرم
# 2                 education        Low      الجيزة     العطارين
# 3                 financial     Medium  الإسكندرية        الهرم
# 4                      food       High    الزقازيق  السيدة زينب
# ...                     ...        ...         ...          ...
# 59995             financial     Medium       أسوان  السيدة زينب
# 59996                  food     Medium    بني سويف  سان ستيفانو
# 59997  disability_equipment     Medium         قنا    مدينة نصر
# 59998                  food        Low       أسوان         شبرا
# 59999                  food       High     القاهرة        الهرم
#
#       number_of_children   age  expense_to_income_ratio  \
# 0                    1.0  49.0                     1.70
# 1                    0.0  37.0                     1.81
# 2                    3.0  22.0                     1.55
# 3                    1.0  47.0                     1.92
# 4                    3.0  64.0                     2.00
# ...                  ...   ...                      ...
# 59995                3.0  22.0                     1.54
# 59996                4.0  46.0                      NaN
# 59997                NaN  28.0                     2.03
# 59998                2.0   NaN                     1.31
# 59999                3.0  52.0                     1.94
#
#                recommended_org  gender
# 0               جمعية الأورمان  female
# 1      جمعية التكافل الاجتماعي    male
# 2                  جمعية رسالة  female
# 3                          NaN     NaN
# 4               جمعية الأورمان  female
# ...                        ...     ...
# 59995  جمعية التكافل الاجتماعي    male
# 59996                      NaN    male
# 59997          مؤسسة مصر الخير  female
# 59998              جمعية رسالة  female
# 59999              جمعية رسالة  female
#
# [60000 rows x 21 columns]

# %%
col = "national_id"
if col in df.columns:
    df[col] = df[col].astype(str).str.strip()
    df.loc[~df[col].str.match(r"^\d{14}$"), col] = "invalid_id"
    print("✔ 'invalid_id'")
# Out:
# ✔ 'invalid_id'

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي إعاقة          3.0  1183629898
# 1               حسن كمال  65150394917789       أيتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       أرملة          8.0  1013124808
# 3        إبراهيم الهواري  46071550347522       أيتام          6.0  1200902016
# 4                    NaN  63352487361031  أسرة فقيرة          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       أيتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       أيتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي إعاقة          3.0  1066819332
# 59998  إبراهيم عبدالفتاح  92279688670624         NaN          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  أسرة فقيرة          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ...  \
# 0      سكن لدى الأقارب  ...
# 1                تمليك  ...
# 2      سكن لدى الأقارب  ...
# 3                تمليك  ...
# 4                تمليك  ...
# ...                ...  ...
# 59995       سكن عشوائي  ...
# 59996            إيجار  ...
# 59997       سكن عشوائي  ...
# 59998            إيجار  ...
# 59999            تمليك  ...
#
#                                             request_text  \
# 0      نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1      حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2      فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3      إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4      آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# ...                                                  ...
# 59995  علي عبدالرحمن من أيتام مقيم في مدينة نصر ويحتا...
# 59996  خالد عبدالباقي من أيتام مقيم في فيصل ويحتاج: ت...
# 59997  صفاء شريف من ذوي إعاقة مقيم في إمبابة ويحتاج: ...
# 59998  إبراهيم عبدالفتاح من أرملة مقيم في السيدة زينب...
# 59999  سعاد عبدالله من أسرة فقيرة مقيم في شبرا ويحتاج...
#
#             assistance_type need_level        city neighborhood  \
# 0      disability_equipment        Low    الزقازيق       إمبابة
# 1                      food       High       سوهاج        الهرم
# 2                 education        Low      الجيزة     العطارين
# 3                 financial     Medium  الإسكندرية        الهرم
# 4                      food       High    الزقازيق  السيدة زينب
# ...                     ...        ...         ...          ...
# 59995             financial     Medium       أسوان  السيدة زينب
# 59996                  food     Medium    بني سويف  سان ستيفانو
# 59997  disability_equipment     Medium         قنا    مدينة نصر
# 59998                  food        Low       أسوان         شبرا
# 59999                  food       High     القاهرة        الهرم
#
#       number_of_children   age  expense_to_income_ratio  \
# 0                    1.0  49.0                     1.70
# 1                    0.0  37.0                     1.81
# 2                    3.0  22.0                     1.55
# 3                    1.0  47.0                     1.92
# 4                    3.0  64.0                     2.00
# ...                  ...   ...                      ...
# 59995                3.0  22.0                     1.54
# 59996                4.0  46.0                      NaN
# 59997                NaN  28.0                     2.03
# 59998                2.0   NaN                     1.31
# 59999                3.0  52.0                     1.94
#
#                recommended_org  gender
# 0               جمعية الأورمان  female
# 1      جمعية التكافل الاجتماعي    male
# 2                  جمعية رسالة  female
# 3                          NaN     NaN
# 4               جمعية الأورمان  female
# ...                        ...     ...
# 59995  جمعية التكافل الاجتماعي    male
# 59996                      NaN    male
# 59997          مؤسسة مصر الخير  female
# 59998              جمعية رسالة  female
# 59999              جمعية رسالة  female
#
# [60000 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# ===========================
# 0) COLUMN NAME
# ===========================
col = "national_id"   # ← غيّريه لو اسمه مختلف

# ===========================
# 1) CLEANING BASIC
# ===========================
if col in df.columns:
    # تحويل لنص
    df[col] = df[col].astype(str)

    # إزالة المسافات والحروف
    df[col] = df[col].str.replace(r"[^\d]", "", regex=True).str.strip()

    # أي حاجة أقل من 14 رقم → invalid
    df.loc[df[col].str.len() != 14, col] = "invalid_id"
else:
    print("❌ العمود غير موجود")

# ===========================
# 2) VALIDATION FUNCTIONS
# ===========================

# قائمة أكواد المحافظات
governorates = {
    "01": "Cairo", "02": "Alexandria", "03": "Port Said", "04": "Suez",
    "11": "Damietta", "12": "Dakahlia", "13": "Sharqia", "14": "Qalyubia",
    "15": "Kafr El Sheikh", "16": "Gharbia", "17": "Monufia", "18": "Beheira",
    "19": "Ismailia", "21": "Giza", "22": "Beni Suef", "23": "Fayoum",
    "24": "Minya", "25": "Assiut", "26": "Sohag", "27": "Qena",
    "28": "Aswan", "29": "Luxor"
}

def get_birthdate(nid):
    century = nid[0]
    year = nid[1:3]
    month = nid[3:5]
    day = nid[5:7]

    # تحديد القرن
    if century == "2":
        full_year = 1900 + int(year)
    elif century == "3":
        full_year = 2000 + int(year)
    else:
        return None

    try:
        return datetime(full_year, int(month), int(day))
    except:
        return None

def valid_governorate(nid):
    code = nid[7:9]
    return code if code in governorates else None

def get_gender(nid):
    serial = int(nid[12])
    return "female" if serial % 2 == 0 else "male"

# Check Digit function
def luhn_checksum(s):
    total = 0
    reverse_digits = s[::-1]
    for i, digit in enumerate(reverse_digits):
        n = int(digit)
        if i % 2 == 1:
            n = n * 2
            if n > 9:
                n -= 9
        total += n
    return total % 10

def check_digit_valid(nid):
    return luhn_checksum(nid[:-1]) == int(nid[-1])

# ===========================
# 3) FULL VALIDATION PIPELINE
# ===========================
def validate_national_id(nid):
    if nid == "invalid_id" or len(nid) != 14:
        return False

    # تاريخ الميلاد
    if get_birthdate(nid) is None:
        return False

    # المحافظة
    if valid_governorate(nid) is None:
        return False

    # check digit
    if not check_digit_valid(nid):
        return False

    return True

df["id_valid"] = df[col].apply(validate_national_id)

# ===========================
# 4) EXTRACT FEATURES
# ===========================
def extract_features(nid):
    if not validate_national_id(nid):
        return pd.Series([None, None, None, None, None])

    birthdate = get_birthdate(nid)
    age = datetime.now().year - birthdate.year

    gov = valid_governorate(nid)
    governorate_name = governorates.get(gov, None)

    gender = get_gender(nid)

    return pd.Series([birthdate, age, gov, governorate_name, gender])

df[["birthdate", "age", "gov_code", "governorate", "gender_from_id"]] = df[col].apply(extract_features)

print("✔clean national_id")
# Out:
# ✔clean national_id

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي إعاقة          3.0  1183629898
# 1               حسن كمال  65150394917789       أيتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       أرملة          8.0  1013124808
# 3        إبراهيم الهواري  46071550347522       أيتام          6.0  1200902016
# 4                    NaN  63352487361031  أسرة فقيرة          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       أيتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       أيتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي إعاقة          3.0  1066819332
# 59998  إبراهيم عبدالفتاح  92279688670624         NaN          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  أسرة فقيرة          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
# df.drop(columns=["birthdate", "age", "gov_code", "governorate", "gender_from_id"], inplace=True)

# %%
import pandas as pd
import re

# تنظيف شامل لعمود الاسم
def clean_name(name):
    if pd.isna(name) or str(name).strip() == "":
        return "غير معروف"

    # تحويل الاسم إلى string
    name = str(name)

    # 1) إزالة المسافات من البداية والنهاية
    name = name.strip()

    # 2) إزالة أي رموز أو أرقام (يبقى بس الحروف العربية والإنجليزية)
    name = re.sub(r'[^A-Za-z\u0600-\u06FF\s]', ' ', name)

    # 3) إزالة المسافات المكررة
    name = re.sub(r'\s+', ' ', name)

    # 4) إزالة التطويل "ــــ"
    name = name.replace("ـ", "")

    # 5) توحيد الهمزات في العربي
    name = (name.replace("أ", "ا")
                .replace("إ", "ا")
                .replace("آ", "ا"))

    # 6) حذف الأسماء القصيرة جدًا (غالبًا غلط)
    if len(name) < 3:
        return "غير معروف"

    # 7) Capitalize للأسماء الإنجليزية
    name = " ".join([w.capitalize() for w in name.split()])

    return name


# تطبيق الدالة على العمود
df["name"] = df["name"].apply(clean_name)

# عرض النتيجة
df[["name", "name"]].head(5)
# Out:
#               name             name
# 0  نجلاء عبدالباسط  نجلاء عبدالباسط
# 1         حسن كمال         حسن كمال
# 2  فاطمة عبدالرحمن  فاطمة عبدالرحمن
# 3  ابراهيم الهواري  ابراهيم الهواري
# 4        غير معروف        غير معروف

# %%
df["name"] = df["name"].apply(clean_name)

# %%
df["name"].head(10)
# Out:
# 0    نجلاء عبدالباسط
# 1           حسن كمال
# 2    فاطمة عبدالرحمن
# 3    ابراهيم الهواري
# 4          غير معروف
# 5          امال انور
# 6      نجلاء عبدالله
# 7        مراد النجار
# 8         محمود انور
# 9        صفاء النجار
# Name: name, dtype: object

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي إعاقة          3.0  1183629898
# 1               حسن كمال  65150394917789       أيتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       أرملة          8.0  1013124808
# 3        ابراهيم الهواري  46071550347522       أيتام          6.0  1200902016
# 4              غير معروف  63352487361031  أسرة فقيرة          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       أيتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       أيتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي إعاقة          3.0  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624         NaN          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  أسرة فقيرة          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
df["case_type"].value_counts()
# Out:
# case_type
# أيتام         11484
# مريض مزمن     11393
# أرملة         11384
# ذوي إعاقة     11353
# أسرة فقيرة    11319
# Name: count, dtype: int64

# %%
import re
import pandas as pd

# ============================
# FUNCTION TO CLEAN ARABIC TEXT
# ============================
def clean_arabic_text(text):
    if pd.isna(text):
        return ""

    text = str(text).strip()

    # Remove tashkeel
    arabic_diacritics = re.compile("""
                                     ّ    |
                                     َ    |
                                     ً    |
                                     ُ    |
                                     ٌ    |
                                     ِ    |
                                     ٍ    |
                                     ْ    |
                                     ـ
                                 """, re.VERBOSE)
    text = re.sub(arabic_diacritics, '', text)

    # Normalize letter forms
    text = re.sub("[إأآا]", "ا", text)
    text = text.replace("ى", "ي")
    text = text.replace("ة", "ه")

    # Remove symbols and numbers
    text = re.sub(r"[^ء-ي\s]", "", text)

    # Collapse extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text


# ================================================
# FUNCTION TO MAP ALL VARIATIONS TO CLEAN CATEGORY
# ================================================
def normalize_case_type(text):
    t = clean_arabic_text(text)

    if t == "":
        return "غير معروف"

    # Mapping Arabic variations → Unified Arabic categories
    mapping = {
        # يتامى
        "ايتام": "ايتام",
        "يتيم": "ايتام",
        "اطفال ايتام": "ايتام",
        "طفل يتيم": "ايتام",

        # أرامل
        "ارمله": "ارمله",
        "ارامل": "ارمله",

        # مرض مزمن
        "مريض مزمن": "مريض مزمن",
        "مرض مزمن": "مريض مزمن",
        "مريض": "مريض مزمن",
        "مزمن": "مريض مزمن",

        # ذوي إعاقة
        "ذوي اعاقه": "ذوي اعاقه",
        "اعاقه": "ذوي اعاقه",
        "معاق": "ذوي اعاقه",

        # أسرة فقيرة
        "اسره فقيره": "اسره فقيره",
        "فقيره": "اسره فقيره",
        "فقير": "اسره فقيره",
        "اسره": "اسره فقيره",
    }

    # Match inside the cleaned text
    for key in mapping:
        if key in t:
            return mapping[key]

    return t  # لو مش موجود في الماب نرجّعه بعد التنضيف


# ============================
# APPLY ON YOUR DATAFRAME
# ============================
df["case_type"] = df["case_type"].apply(normalize_case_type)

print("case_type Done ✔️")
# Out:
# case_type Done ✔️

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه          3.0  1183629898
# 1               حسن كمال  65150394917789       ايتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله          8.0  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام          6.0  1200902016
# 4              غير معروف  63352487361031  اسره فقيره          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه          3.0  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
df["case_type"] = df["case_type"].apply(normalize_case_type)

# %%
df["case_type"] = df["case_type"].apply(normalize_case_type)

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه          3.0  1183629898
# 1               حسن كمال  65150394917789       ايتام          4.0  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله          8.0  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام          6.0  1200902016
# 4              غير معروف  63352487361031  اسره فقيره          7.0  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام          3.0  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام          7.0  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه          3.0  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف          7.0  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره          3.0  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
df["family_size"].value_counts()
# Out:
# family_size
# 4.0    8378
# 3.0    8246
# 6.0    8216
# 5.0    8082
# 2.0    8053
# 8.0    8042
# 7.0    8004
# Name: count, dtype: int64

# %%
df["family_size"] = pd.to_numeric(df["family_size"], errors="coerce")
df["family_size"] = df["family_size"].fillna(df["family_size"].median())
df.loc[df["family_size"] <= 0, "family_size"] = df["family_size"].median()
df["family_size"] = df["family_size"].astype(int)

# %%
df.head(20)
# Out:
#                name     national_id   case_type  family_size       phone  \
# 0   نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1          حسن كمال  65150394917789       ايتام            4  1014613636
# 2   فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3   ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4         غير معروف  63352487361031  اسره فقيره            7  1529047284
# 5         امال انور  89658472227676       ارمله            2  1010017824
# 6     نجلاء عبدالله  51253738857239  اسره فقيره            2  1553270901
# 7       مراد النجار  95445940865922   ذوي اعاقه            8  1147055689
# 8        محمود انور  85678021986931       ايتام            3  1100123185
# 9       صفاء النجار  23198139775396   ذوي اعاقه            8  1546434338
# 10         علي مراد  40303468423610       ارمله            7  1032755810
# 11       محمود سليم  36102411705718  اسره فقيره            8  1133402148
# 12  امينة عبدالباسط  51519304333141       ايتام            3  1019702166
# 13      علي عبدالله  12333086288631   مريض مزمن            5  1570588449
# 14   مراد عبدالرحمن  67321016798224       ايتام            4  1155751227
# 15    علي عبدالباسط  46978018111616  اسره فقيره            6  1596678143
# 16  اسماء عبدالباسط      invalid_id       ايتام            5  1078280807
# 17  مصطفى عبدالباقي  58471964965744       ايتام            7  1124578465
# 18        سليم يوسف  10083506731202  اسره فقيره            2  1018629106
# 19       اسماء سليم  85776895049789       ارمله            3  1184941278
#
#     amount_received  income_monthly  monthly_expenses    debts  \
# 0             200.0          1798.0            3050.0      0.0
# 1            1000.0          3497.0            6328.0   8961.0
# 2            1500.0          2482.0               NaN      0.0
# 3             600.0          2873.0            5516.0      0.0
# 4            1500.0          3101.0            6208.0  10983.0
# 5             800.0          2530.0            5243.0  14473.0
# 6             600.0          2007.0            4643.0      0.0
# 7               0.0             NaN            4452.0   3034.0
# 8            1000.0          2981.0            6848.0      NaN
# 9             300.0          3184.0            4938.0      0.0
# 10            300.0          2927.0            4000.0      0.0
# 11           2000.0          3519.0               NaN      0.0
# 12           1000.0          1273.0            1710.0  16047.0
# 13           2000.0          3120.0            5848.0   8541.0
# 14            800.0          2568.0            5645.0      0.0
# 15            200.0          2887.0            4227.0      0.0
# 16           2000.0          1815.0            3951.0      0.0
# 17           1000.0          2480.0            4307.0      0.0
# 18            800.0          3251.0            5016.0  11737.0
# 19            500.0           710.0            1725.0  29192.0
#
#        housing_type  ... number_of_children age expense_to_income_ratio  \
# 0   سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1             تمليك  ...                0.0 NaN                    1.81
# 2   سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3             تمليك  ...                1.0 NaN                    1.92
# 4             تمليك  ...                3.0 NaN                    2.00
# 5         سكن حكومي  ...                1.0 NaN                    2.07
# 6             إيجار  ...                2.0 NaN                    2.31
# 7             تمليك  ...                NaN NaN                    1.82
# 8        سكن عشوائي  ...                2.0 NaN                    2.30
# 9               NaN  ...                2.0 NaN                    1.55
# 10            إيجار  ...                0.0 NaN                    1.37
# 11            إيجار  ...                5.0 NaN                    2.14
# 12        سكن حكومي  ...                3.0 NaN                    1.34
# 13              NaN  ...                1.0 NaN                    1.87
# 14            تمليك  ...                2.0 NaN                    2.20
# 15       سكن عشوائي  ...                0.0 NaN                    1.46
# 16  سكن لدى الأقارب  ...                6.0 NaN                    2.18
# 17            إيجار  ...                4.0 NaN                    1.74
# 18            تمليك  ...                1.0 NaN                    1.54
# 19            تمليك  ...                3.0 NaN                    2.43
#
#             recommended_org  gender id_valid  birthdate  gov_code  \
# 0            جمعية الأورمان  female    False        NaT      None
# 1   جمعية التكافل الاجتماعي    male    False        NaT      None
# 2               جمعية رسالة  female    False        NaT      None
# 3                       NaN     NaN    False        NaT      None
# 4            جمعية الأورمان  female    False        NaT      None
# 5                       NaN  female    False        NaT      None
# 6            جمعية الأورمان  female    False        NaT      None
# 7            جمعية الأورمان    male    False        NaT      None
# 8   جمعية الباقيات الصالحات    male    False        NaT      None
# 9   جمعية التكافل الاجتماعي  female    False        NaT      None
# 10          مؤسسة مصر الخير  female    False        NaT      None
# 11              جمعية رسالة    male    False        NaT      None
# 12  جمعية التكافل الاجتماعي  female    False        NaT      None
# 13  جمعية التكافل الاجتماعي    male    False        NaT      None
# 14              جمعية رسالة    male    False        NaT      None
# 15  جمعية الباقيات الصالحات    male    False        NaT      None
# 16  جمعية الباقيات الصالحات  female    False        NaT      None
# 17                      NaN    male    False        NaT      None
# 18              جمعية رسالة    male    False        NaT      None
# 19  جمعية الباقيات الصالحات  female    False        NaT      None
#
#     governorate gender_from_id
# 0          None           None
# 1          None           None
# 2          None           None
# 3          None           None
# 4          None           None
# 5          None           None
# 6          None           None
# 7          None           None
# 8          None           None
# 9          None           None
# 10         None           None
# 11         None           None
# 12         None           None
# 13         None           None
# 14         None           None
# 15         None           None
# 16         None           None
# 17         None           None
# 18         None           None
# 19         None           None
#
# [20 rows x 26 columns]

# %%
# إزالة أي حاجة مش رقم
df["phone"] = df["phone"].astype(str).str.replace(r"[^0-9]", "", regex=True)

# التحقق من الطول (مثلا لازم 11 رقم)
df.loc[df["phone"].str.len() != 10, "phone"] = "unknown"

# ملء القيم الفاضية
df["phone"] = df["phone"].replace({"": "unknown", "nan": "unknown"})

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0          1798.0            3050.0      0.0
# 1               1000.0          3497.0            6328.0   8961.0
# 2               1500.0          2482.0               NaN      0.0
# 3                600.0          2873.0            5516.0      0.0
# 4               1500.0          3101.0            6208.0  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0          3021.0            4668.0    960.0
# 59996            500.0          1457.0            3116.0      0.0
# 59997           2000.0          3518.0            7141.0      0.0
# 59998            800.0          1501.0            1962.0      0.0
# 59999            800.0          2738.0            5309.0  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          57009 non-null  float64
#  6   income_monthly           57073 non-null  float64
#  7   monthly_expenses         57060 non-null  float64
#  8   debts                    57014 non-null  float64
#  9   housing_type             56982 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(1), object(16)
# memory usage: 11.5+ MB

# %%
df["amount_received"].value_counts()
# Out:
# amount_received
# 300.0     6523
# 800.0     6418
# 1000.0    6356
# 500.0     6331
# 2000.0    6328
# 200.0     6321
# 0.0       6282
# 600.0     6251
# 1500.0    6199
# Name: count, dtype: int64

# %%
import re
import numpy as np

# خريطة الكلمات العربية → أرقام
arabic_numbers_map = {
    "صفر": 0, "واحد": 1, "اتنين": 2, "اثنين": 2, "تلاته": 3, "اربعه": 4,
    "خمسه": 5, "سته": 6, "سبعه": 7, "تمانيه": 8, "تسعه": 9, "عشره": 10,
    "مية": 100, "ميه": 100, "الف": 1000, "الفين": 2000, "تلاتلاف": 3000
}

def text_to_number(text):
    for word, value in arabic_numbers_map.items():
        if word in text:
            return value
    return None


def clean_amount_received(x):
    original = str(x).strip().lower()

    # 1) لو فاضي
    if original in ["", "nan", "none", "null", "-", "—"]:
        return np.nan

    # 2) لو مكتوب بالعربي (مثال: الف، مية، خمسمية)
    text_val = text_to_number(original)
    if text_val is not None:
        return float(text_val)

    # 3) إزالة العملات (جنيه، دولار…)
    clean = re.sub(r"(جنيه|جنيهات|ريال|دولار|egp|usd|\$)", "", original)

    # 4) تصحيح "O" بدل 0
    clean = clean.replace("o", "0")

    # 5) إزالة أي شيء غير أرقام أو نقطة
    clean = re.sub(r"[^\d\.]", "", clean)

    if clean == "":
        return np.nan

    # 6) تحويل لرقم
    try:
        val = float(clean)
    except:
        return np.nan

    # 7) إصلاح السالب
    if val < 0:
        val = 0

    # 8) outliers غير منطقية
    if val > 50000:
        return np.nan

    return val


# تطبيق التنضيف **على نفس العمود**
df["amount_received"] = df["amount_received"].apply(clean_amount_received)

# ملء القيم الناقصة بالمتوسط أو الميديان
df["amount_received"].fillna(df["amount_received"].median(), inplace=True)

# تأكيد النوع
df["amount_received"] = df["amount_received"].astype(float)

print("✔️ amount_received اتنضف واتحدّث في نفس العمود ✨")
# Out:
# ✔️ amount_received اتنضف واتحدّث في نفس العمود ✨
# /tmp/ipython-input-3324644226.py:63: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["amount_received"].fillna(df["amount_received"].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           57073 non-null  float64
#  7   monthly_expenses         57060 non-null  float64
#  8   debts                    57014 non-null  float64
#  9   housing_type             56982 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(1), object(16)
# memory usage: 11.5+ MB

# %%
df["income_monthly"].value_counts()
# Out:
# income_monthly
# 600.0     193
# 2298.0     48
# 2563.0     47
# 2373.0     46
# 2643.0     46
#          ...
# 4571.0      1
# 4770.0      1
# 4184.0      1
# 4774.0      1
# 638.0       1
# Name: count, Length: 3819, dtype: int64

# %%
# ----- 1) Copy to avoid modifying the original if needed -----
df["income_monthly"] = df["income_monthly"].astype(str)

# ----- 2) Remove currencies, words, spaces, commas -----
df["income_monthly"] = (
    df["income_monthly"]
    .str.replace(r"[^\d]", "", regex=True)   # keep digits ONLY
)

# ----- 3) Replace empty strings with NaN -----
df["income_monthly"].replace("", pd.NA, inplace=True)

# ----- 4) Convert to numeric -----
df["income_monthly"] = pd.to_numeric(df["income_monthly"], errors="coerce")

# ----- 5) Remove negative values -----
df.loc[df["income_monthly"] < 0, "income_monthly"] = pd.NA

# ----- 6) Remove extremely large unrealistic incomes (outliers) -----
df.loc[df["income_monthly"] > 100000, "income_monthly"] = pd.NA

# ----- 7) Fill missing values with the median (best practice for income) -----
median_income = df["income_monthly"].median()
df["income_monthly"].fillna(median_income, inplace=True)

# ----- 8) Convert to integer -----
df["income_monthly"] = df["income_monthly"].astype(int)
# Out:
# /tmp/ipython-input-410188006.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["income_monthly"].replace("", pd.NA, inplace=True)
# /tmp/ipython-input-410188006.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["income_monthly"].fillna(median_income, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         57060 non-null  float64
#  8   debts                    57014 non-null  float64
#  9   housing_type             56982 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(6), int64(2), object(16)
# memory usage: 11.5+ MB

# %%
# ----- 1) Ensure the column is string -----
df["monthly_expenses"] = df["monthly_expenses"].astype(str)

# ----- 2) Remove all non-digit characters -----
df["monthly_expenses"] = (
    df["monthly_expenses"]
    .str.replace(r"[^\d]", "", regex=True)   # keep digits ONLY
)

# ----- 3) Replace empty strings with NaN -----
df["monthly_expenses"].replace("", pd.NA, inplace=True)

# ----- 4) Convert to numeric -----
df["monthly_expenses"] = pd.to_numeric(df["monthly_expenses"], errors="coerce")

# ----- 5) Remove negative values -----
df.loc[df["monthly_expenses"] < 0, "monthly_expenses"] = pd.NA

# ----- 6) Remove unrealistic large values -----
df.loc[df["monthly_expenses"] > 100000, "monthly_expenses"] = pd.NA

# ----- 7) Fill missing values with median -----
median_expenses = df["monthly_expenses"].median()
df["monthly_expenses"].fillna(median_expenses, inplace=True)

# ----- 8) Convert to integer -----
df["monthly_expenses"] = df["monthly_expenses"].astype(int)
# Out:
# /tmp/ipython-input-666171365.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["monthly_expenses"].replace("", pd.NA, inplace=True)
# /tmp/ipython-input-666171365.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["monthly_expenses"].fillna(median_expenses, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    57014 non-null  float64
#  9   housing_type             56982 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(5), int64(3), object(16)
# memory usage: 11.5+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# ---------------------
# 1) Scatter Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='income_monthly', y='monthly_expenses', data=df)
plt.title("Scatter Plot: Income vs Expenses")
plt.xlabel("Monthly Income")
plt.ylabel("Monthly Expenses")
plt.show()

# ---------------------
# 2) Boxplot
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['income_monthly', 'monthly_expenses']])
plt.title("Boxplot: Income vs Expenses")
plt.show()

# ---------------------
# 3) Histogram
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['income_monthly'], kde=True, bins=30, color='skyblue')
plt.title("Histogram: Monthly Income")
plt.subplot(1,2,2)
sns.histplot(df['monthly_expenses'], kde=True, bins=30, color='salmon')
plt.title("Histogram: Monthly Expenses")
plt.show()

# ---------------------
# 4) Correlation heatmap
plt.figure(figsize=(6,4))
sns.heatmap(df[['income_monthly', 'monthly_expenses']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between Income and Expenses")
plt.show()

# ---------------------
# 5) Comparison statistics
comparison_stats = df[['income_monthly', 'monthly_expenses']].describe()
print(comparison_stats)
# Out:
#        income_monthly  monthly_expenses
# count    60000.000000      60000.000000
# mean     24979.969333      46008.218000
# std       6820.430742      15555.986278
# min       6000.000000       7260.000000
# 25%      20560.000000      35140.000000
# 50%      24990.000000      44650.000000
# 75%      29400.000000      55520.000000
# max      57920.000000      99910.000000

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender id_valid  birthdate  gov_code  \
# 0               جمعية الأورمان  female    False        NaT      None
# 1      جمعية التكافل الاجتماعي    male    False        NaT      None
# 2                  جمعية رسالة  female    False        NaT      None
# 3                          NaN     NaN    False        NaT      None
# 4               جمعية الأورمان  female    False        NaT      None
# ...                        ...     ...      ...        ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False        NaT      None
# 59996                      NaN    male    False        NaT      None
# 59997          مؤسسة مصر الخير  female    False        NaT      None
# 59998              جمعية رسالة  female    False        NaT      None
# 59999              جمعية رسالة  female    False        NaT      None
#
#        governorate gender_from_id
# 0             None           None
# 1             None           None
# 2             None           None
# 3             None           None
# 4             None           None
# ...            ...            ...
# 59995         None           None
# 59996         None           None
# 59997         None           None
# 59998         None           None
# 59999         None           None
#
# [60000 rows x 26 columns]

# %%
import pandas as pd
import numpy as np
import re

# 1) تحويل القيم الرقمية (لو فيه نصوص فيها أرقام)
def clean_numeric(x):
    if pd.isna(x):
        return np.nan
    x_str = str(x)
    x_str = re.sub(r'[^\d.]', '', x_str)  # نشيل أي حاجة مش رقم أو نقطة
    if x_str == '':
        return np.nan
    return float(x_str)

df['debts'] = df['debts'].apply(clean_numeric)

# 2) التعامل مع القيم المفقودة
# ممكن تعملي:
# a) استبدالها بصفر لو مش مهم
# b) استبدالها بالمتوسط أو الوسيط Median
median_debt = df['debts'].median()
df['debts'].fillna(median_debt, inplace=True)

# 3) التأكد إن القيم موجبة ومنطقية
df['debts'] = df['debts'].apply(lambda x: x if x >= 0 else median_debt)

# 4) التعامل مع القيم المتطرفة (Outliers)
# مثلا أي قيمة أكبر من 99th percentile نستبدلها بالحد الأعلى المقبول
upper_limit = df['debts'].quantile(0.99)
df['debts'] = df['debts'].apply(lambda x: x if x <= upper_limit else upper_limit)
# Out:
# /tmp/ipython-input-3984809012.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['debts'].fillna(median_debt, inplace=True)

# %%
df['debt_to_income_ratio'] = df['debts'] / df['income_monthly']

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ... age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ... NaN                    1.70
# 1                تمليك  ... NaN                    1.81
# 2      سكن لدى الأقارب  ... NaN                    1.55
# 3                تمليك  ... NaN                    1.92
# 4                تمليك  ... NaN                    2.00
# ...                ...  ...  ..                     ...
# 59995       سكن عشوائي  ... NaN                    1.54
# 59996            إيجار  ... NaN                     NaN
# 59997       سكن عشوائي  ... NaN                    2.03
# 59998            إيجار  ... NaN                    1.31
# 59999            تمليك  ... NaN                    1.94
#
#                recommended_org  gender id_valid birthdate  gov_code  \
# 0               جمعية الأورمان  female    False       NaT      None
# 1      جمعية التكافل الاجتماعي    male    False       NaT      None
# 2                  جمعية رسالة  female    False       NaT      None
# 3                          NaN     NaN    False       NaT      None
# 4               جمعية الأورمان  female    False       NaT      None
# ...                        ...     ...      ...       ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False       NaT      None
# 59996                      NaN    male    False       NaT      None
# 59997          مؤسسة مصر الخير  female    False       NaT      None
# 59998              جمعية رسالة  female    False       NaT      None
# 59999              جمعية رسالة  female    False       NaT      None
#
#        governorate  gender_from_id debt_to_income_ratio
# 0             None            None             0.000000
# 1             None            None             0.256248
# 2             None            None             0.000000
# 3             None            None             0.000000
# 4             None            None             0.354176
# ...            ...             ...                  ...
# 59995         None            None             0.031778
# 59996         None            None             0.000000
# 59997         None            None             0.000000
# 59998         None            None             0.000000
# 59999         None            None             0.459569
#
# [60000 rows x 27 columns]

# %%
df["housing_type"].value_counts()
# Out:
# housing_type
# تمليك              11508
# سكن حكومي          11487
# سكن عشوائي         11413
# إيجار              11330
# سكن لدى الأقارب    11244
# Name: count, dtype: int64

# %%
# 1️⃣ املأ القيم المفقودة قبل أي تحويل
most_common_housing = df['housing_type'].mode()[0]
df['housing_type'] = df['housing_type'].fillna(most_common_housing)

# 2️⃣ تحويل القيم لنصوص واضحة + إزالة المسافات
df['housing_type'] = df['housing_type'].astype(str).str.strip()

# 3️⃣ توحيد الأسماء لو فيه اختلافات في الكتابة
df['housing_type'] = df['housing_type'].replace({
    'سكن حكومى': 'سكن حكومي',
    'سكن عشوائى': 'سكن عشوائي',
    'مقيم في شبرا':'مقيم فى شبرا'
})

# 4️⃣ التأكد من القيم النهائية
print(df['housing_type'].value_counts())
# Out:
# housing_type
# تمليك              14526
# سكن حكومي          11487
# سكن عشوائي         11413
# إيجار              11330
# سكن لدى الأقارب    11244
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x='housing_type', data=df, order=df['housing_type'].value_counts().index)
plt.title("Distribution of Housing Types")
plt.xlabel("Housing Type")
plt.ylabel("Count")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            57116 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
#  26  debt_to_income_ratio     60000 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(6), int64(3), object(16)
# memory usage: 12.0+ MB

# %%
df["health_status"].value_counts()
# Out:
# health_status
# مريض ضغط       9610
# إعاقة ذهنية    9609
# قلب            9522
# مريض سكر       9514
# إعاقة حركية    9477
# سليم           9384
# Name: count, dtype: int64

# %%
import pandas as pd


df['health_status'] = df['health_status'].replace("nan", pd.NA)

# 2) تنسيق النصوص
df['health_status'] = df['health_status'].astype(str).str.lower().str.strip()

# 3) توحيد المسميات
df['health_status'] = df['health_status'].replace({
    'سكر': 'مريض سكر',
    'مريض سكرى': 'مريض سكر',
    'ضغط': 'مريض ضغط',
    'قلب': 'قلب',
    'اعاقة حركية': 'إعاقة حركية',
    'اعاقة ذهنية': 'إعاقة ذهنية',
    'إعاقة حركية': 'إعاقة حركية',
    'إعاقة ذهنية': 'إعاقة ذهنية',
    'سليم': 'سليم',
    'unknown': 'غير معروف',
    '-': 'غير معروف',
    'nan': pd.NA
})

# 4) إكمال المفقود
most_common = df['health_status'].mode()[0]
df['health_status'] = df['health_status'].fillna(most_common)

print(df['health_status'].value_counts())
# Out:
# health_status
# مريض ضغط       12494
# إعاقة ذهنية     9609
# قلب             9522
# مريض سكر        9514
# إعاقة حركية     9477
# سليم            9384
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.countplot(x='health_status', data=df, order=df['health_status'].value_counts().index)
plt.title("Distribution of Health Status")
plt.xlabel("Health Status")
plt.ylabel("Count")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  id_valid                 60000 non-null  bool
#  22  birthdate                13 non-null     datetime64[ns]
#  23  gov_code                 13 non-null     object
#  24  governorate              13 non-null     object
#  25  gender_from_id           13 non-null     object
#  26  debt_to_income_ratio     60000 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(6), int64(3), object(16)
# memory usage: 12.0+ MB

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ... age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ... NaN                    1.70
# 1                تمليك  ... NaN                    1.81
# 2      سكن لدى الأقارب  ... NaN                    1.55
# 3                تمليك  ... NaN                    1.92
# 4                تمليك  ... NaN                    2.00
# ...                ...  ...  ..                     ...
# 59995       سكن عشوائي  ... NaN                    1.54
# 59996            إيجار  ... NaN                     NaN
# 59997       سكن عشوائي  ... NaN                    2.03
# 59998            إيجار  ... NaN                    1.31
# 59999            تمليك  ... NaN                    1.94
#
#                recommended_org  gender id_valid birthdate  gov_code  \
# 0               جمعية الأورمان  female    False       NaT      None
# 1      جمعية التكافل الاجتماعي    male    False       NaT      None
# 2                  جمعية رسالة  female    False       NaT      None
# 3                          NaN     NaN    False       NaT      None
# 4               جمعية الأورمان  female    False       NaT      None
# ...                        ...     ...      ...       ...       ...
# 59995  جمعية التكافل الاجتماعي    male    False       NaT      None
# 59996                      NaN    male    False       NaT      None
# 59997          مؤسسة مصر الخير  female    False       NaT      None
# 59998              جمعية رسالة  female    False       NaT      None
# 59999              جمعية رسالة  female    False       NaT      None
#
#        governorate  gender_from_id debt_to_income_ratio
# 0             None            None             0.000000
# 1             None            None             0.256248
# 2             None            None             0.000000
# 3             None            None             0.000000
# 4             None            None             0.354176
# ...            ...             ...                  ...
# 59995         None            None             0.031778
# 59996         None            None             0.000000
# 59997         None            None             0.000000
# 59998         None            None             0.000000
# 59999         None            None             0.459569
#
# [60000 rows x 27 columns]

# %%
df.drop(columns=["id_valid"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             56989 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  age                      13 non-null     float64
#  18  expense_to_income_ratio  57127 non-null  float64
#  19  recommended_org          56972 non-null  object
#  20  gender                   56985 non-null  object
#  21  birthdate                13 non-null     datetime64[ns]
#  22  gov_code                 13 non-null     object
#  23  governorate              13 non-null     object
#  24  gender_from_id           13 non-null     object
#  25  debt_to_income_ratio     60000 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(16)
# memory usage: 11.9+ MB

# %%
df.isna().sum()
# Out:
# name                           0
# national_id                    0
# case_type                      0
# family_size                    0
# phone                          0
# amount_received                0
# income_monthly                 0
# monthly_expenses               0
# debts                          0
# housing_type                   0
# health_status                  0
# request_text                3011
# assistance_type             3012
# need_level                  2995
# city                        2931
# neighborhood                2962
# number_of_children          3046
# age                        59987
# expense_to_income_ratio     2873
# recommended_org             3028
# gender                      3015
# birthdate                  59987
# gov_code                   59987
# governorate                59987
# gender_from_id             59987
# debt_to_income_ratio           0
# dtype: int64

# %%
df["request_text"].value_counts()
# Out:
# request_text
# محمد شريف من مريض مزمن مقيم في إمبابة ويحتاج: تحتاج علاج وأدوية لمتابعة الحالة الصحية.         10
# أحمد مراد من مريض مزمن مقيم في فيصل ويحتاج: تحتاج علاج وأدوية لمتابعة الحالة الصحية.           10
# هند عبدالرحمن من مريض مزمن مقيم في المطرية ويحتاج: تحتاج علاج وأدوية لمتابعة الحالة الصحية.     9
# مصطفى عبدالله من مريض مزمن مقيم في المطرية ويحتاج: تحتاج علاج وأدوية لمتابعة الحالة الصحية.     9
# مصطفى النجار من مريض مزمن مقيم في المعادي ويحتاج: تحتاج علاج وأدوية لمتابعة الحالة الصحية.      9
#                                                                                                ..
# مصطفى عبدالفتاح من أيتام مقيم في مدينة نصر ويحتاج: تحتاج سلة غذائية شهرية بسبب ضعف الدخل.       1
# سلمى يوسف من أرملة مقيم في شبرا ويحتاج: تحتاج سلة غذائية شهرية بسبب ضعف الدخل.                  1
# إبراهيم يوسف من أرملة مقيم في المعادي ويحتاج: تحتاج سلة غذائية شهرية بسبب ضعف الدخل.            1
# مريم النجار من أيتام مقيم في عين شمس ويحتاج: تحتاج مساعدة مالية لتغطية مصاريف المعيشة.          1
# سعاد الهواري من أرملة مقيم في المحلة الكبرى ويحتاج: تحتاج مصاريف مدارس للدروس والكتب.           1
# Name: count, Length: 33144, dtype: int64

# %%
import pandas as pd
import re

def clean_request_text(text):

    # لو القيمة NaN
    if pd.isna(text):
        return "غير معروف"

    # نحول أي نوع لنص
    text = str(text).strip()

    if text == "":
        return "غير معروف"

    # إزالة الرموز الزيادة ويكون نص نظيف فقط
    text_clean = re.sub(r'[^0-9\u0600-\u06FF\s:]', ' ', text)
    text_clean = re.sub(r'\s+', ' ', text_clean).strip()

    return text_clean

# تطبيق الدالة على العمود
df["request_text"] = df["request_text"].apply(clean_request_text)

df.head()
# Out:
#               name     national_id   case_type  family_size       phone  \
# 0  نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1         حسن كمال  65150394917789       ايتام            4  1014613636
# 2  فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3  ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4        غير معروف  63352487361031  اسره فقيره            7  1529047284
#
#    amount_received  income_monthly  monthly_expenses    debts  \
# 0            200.0           17980             30500      0.0
# 1           1000.0           34970             63280   8961.0
# 2           1500.0           24820             44650      0.0
# 3            600.0           28730             55160      0.0
# 4           1500.0           31010             62080  10983.0
#
#       housing_type  ... number_of_children age expense_to_income_ratio  \
# 0  سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1            تمليك  ...                0.0 NaN                    1.81
# 2  سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3            تمليك  ...                1.0 NaN                    1.92
# 4            تمليك  ...                3.0 NaN                    2.00
#
#            recommended_org  gender birthdate  gov_code  governorate  \
# 0           جمعية الأورمان  female       NaT      None         None
# 1  جمعية التكافل الاجتماعي    male       NaT      None         None
# 2              جمعية رسالة  female       NaT      None         None
# 3                      NaN     NaN       NaT      None         None
# 4           جمعية الأورمان  female       NaT      None         None
#
#    gender_from_id debt_to_income_ratio
# 0            None             0.000000
# 1            None             0.256248
# 2            None             0.000000
# 3            None             0.000000
# 4            None             0.354176
#
# [5 rows x 26 columns]

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ... number_of_children age expense_to_income_ratio  \
# 0      سكن لدى الأقارب  ...                1.0 NaN                    1.70
# 1                تمليك  ...                0.0 NaN                    1.81
# 2      سكن لدى الأقارب  ...                3.0 NaN                    1.55
# 3                تمليك  ...                1.0 NaN                    1.92
# 4                تمليك  ...                3.0 NaN                    2.00
# ...                ...  ...                ...  ..                     ...
# 59995       سكن عشوائي  ...                3.0 NaN                    1.54
# 59996            إيجار  ...                4.0 NaN                     NaN
# 59997       سكن عشوائي  ...                NaN NaN                    2.03
# 59998            إيجار  ...                2.0 NaN                    1.31
# 59999            تمليك  ...                3.0 NaN                    1.94
#
#                recommended_org  gender birthdate  gov_code  governorate  \
# 0               جمعية الأورمان  female       NaT      None         None
# 1      جمعية التكافل الاجتماعي    male       NaT      None         None
# 2                  جمعية رسالة  female       NaT      None         None
# 3                          NaN     NaN       NaT      None         None
# 4               جمعية الأورمان  female       NaT      None         None
# ...                        ...     ...       ...       ...          ...
# 59995  جمعية التكافل الاجتماعي    male       NaT      None         None
# 59996                      NaN    male       NaT      None         None
# 59997          مؤسسة مصر الخير  female       NaT      None         None
# 59998              جمعية رسالة  female       NaT      None         None
# 59999              جمعية رسالة  female       NaT      None         None
#
#        gender_from_id debt_to_income_ratio
# 0                None             0.000000
# 1                None             0.256248
# 2                None             0.000000
# 3                None             0.000000
# 4                None             0.354176
# ...               ...                  ...
# 59995            None             0.031778
# 59996            None             0.000000
# 59997            None             0.000000
# 59998            None             0.000000
# 59999            None             0.459569
#
# [60000 rows x 26 columns]

# %%
df.drop(columns=["age"], inplace=True)

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ... neighborhood number_of_children  \
# 0      سكن لدى الأقارب  ...       إمبابة                1.0
# 1                تمليك  ...        الهرم                0.0
# 2      سكن لدى الأقارب  ...     العطارين                3.0
# 3                تمليك  ...        الهرم                1.0
# 4                تمليك  ...  السيدة زينب                3.0
# ...                ...  ...          ...                ...
# 59995       سكن عشوائي  ...  السيدة زينب                3.0
# 59996            إيجار  ...  سان ستيفانو                4.0
# 59997       سكن عشوائي  ...    مدينة نصر                NaN
# 59998            إيجار  ...         شبرا                2.0
# 59999            تمليك  ...        الهرم                3.0
#
#       expense_to_income_ratio          recommended_org  gender birthdate  \
# 0                        1.70           جمعية الأورمان  female       NaT
# 1                        1.81  جمعية التكافل الاجتماعي    male       NaT
# 2                        1.55              جمعية رسالة  female       NaT
# 3                        1.92                      NaN     NaN       NaT
# 4                        2.00           جمعية الأورمان  female       NaT
# ...                       ...                      ...     ...       ...
# 59995                    1.54  جمعية التكافل الاجتماعي    male       NaT
# 59996                     NaN                      NaN    male       NaT
# 59997                    2.03          مؤسسة مصر الخير  female       NaT
# 59998                    1.31              جمعية رسالة  female       NaT
# 59999                    1.94              جمعية رسالة  female       NaT
#
#        gov_code  governorate gender_from_id debt_to_income_ratio
# 0          None         None           None             0.000000
# 1          None         None           None             0.256248
# 2          None         None           None             0.000000
# 3          None         None           None             0.000000
# 4          None         None           None             0.354176
# ...         ...          ...            ...                  ...
# 59995      None         None           None             0.031778
# 59996      None         None           None             0.000000
# 59997      None         None           None             0.000000
# 59998      None         None           None             0.000000
# 59999      None         None           None             0.459569
#
# [60000 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  expense_to_income_ratio  57127 non-null  float64
#  18  recommended_org          56972 non-null  object
#  19  gender                   56985 non-null  object
#  20  birthdate                13 non-null     datetime64[ns]
#  21  gov_code                 13 non-null     object
#  22  governorate              13 non-null     object
#  23  gender_from_id           13 non-null     object
#  24  debt_to_income_ratio     60000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(16)
# memory usage: 11.4+ MB

# %%
df.drop(columns=[
    "birthdate",
    "gov_code",
    "governorate",
    "gender_from_id"

], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          56988 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  expense_to_income_ratio  57127 non-null  float64
#  18  recommended_org          56972 non-null  object
#  19  gender                   56985 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(5), int64(3), object(13)
# memory usage: 9.6+ MB

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ...  \
# 0      سكن لدى الأقارب  ...
# 1                تمليك  ...
# 2      سكن لدى الأقارب  ...
# 3                تمليك  ...
# 4                تمليك  ...
# ...                ...  ...
# 59995       سكن عشوائي  ...
# 59996            إيجار  ...
# 59997       سكن عشوائي  ...
# 59998            إيجار  ...
# 59999            تمليك  ...
#
#                                             request_text  \
# 0      نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1      حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2      فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3      إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4      آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# ...                                                  ...
# 59995  علي عبدالرحمن من أيتام مقيم في مدينة نصر ويحتا...
# 59996  خالد عبدالباقي من أيتام مقيم في فيصل ويحتاج: ت...
# 59997  صفاء شريف من ذوي إعاقة مقيم في إمبابة ويحتاج: ...
# 59998  إبراهيم عبدالفتاح من أرملة مقيم في السيدة زينب...
# 59999  سعاد عبدالله من أسرة فقيرة مقيم في شبرا ويحتاج...
#
#             assistance_type need_level        city neighborhood  \
# 0      disability_equipment        Low    الزقازيق       إمبابة
# 1                      food       High       سوهاج        الهرم
# 2                 education        Low      الجيزة     العطارين
# 3                 financial     Medium  الإسكندرية        الهرم
# 4                      food       High    الزقازيق  السيدة زينب
# ...                     ...        ...         ...          ...
# 59995             financial     Medium       أسوان  السيدة زينب
# 59996                  food     Medium    بني سويف  سان ستيفانو
# 59997  disability_equipment     Medium         قنا    مدينة نصر
# 59998                  food        Low       أسوان         شبرا
# 59999                  food       High     القاهرة        الهرم
#
#       number_of_children  expense_to_income_ratio          recommended_org  \
# 0                    1.0                     1.70           جمعية الأورمان
# 1                    0.0                     1.81  جمعية التكافل الاجتماعي
# 2                    3.0                     1.55              جمعية رسالة
# 3                    1.0                     1.92                      NaN
# 4                    3.0                     2.00           جمعية الأورمان
# ...                  ...                      ...                      ...
# 59995                3.0                     1.54  جمعية التكافل الاجتماعي
# 59996                4.0                      NaN                      NaN
# 59997                NaN                     2.03          مؤسسة مصر الخير
# 59998                2.0                     1.31              جمعية رسالة
# 59999                3.0                     1.94              جمعية رسالة
#
#        gender debt_to_income_ratio
# 0      female             0.000000
# 1        male             0.256248
# 2      female             0.000000
# 3         NaN             0.000000
# 4      female             0.354176
# ...       ...                  ...
# 59995    male             0.031778
# 59996    male             0.000000
# 59997  female             0.000000
# 59998  female             0.000000
# 59999  female             0.459569
#
# [60000 rows x 21 columns]

# %%
df["assistance_type"].value_counts()
# Out:
# assistance_type
# medical                 15296
# food                    11441
# financial               11332
# education                7669
# housing                  7494
# disability_equipment     3756
# Name: count, dtype: int64

# %%
# تحويل النص لصيغة موحدة
df["assistance_type"] = (
    df["assistance_type"]
    .astype(str)
    .str.strip()
    .str.lower()
)
# قاموس تصحيح القيم
mapping = {
    "med": "medical",
    "medic": "medical",
    "medical": "medical",
    "food": "food",
    "fd": "food",
    "financial": "financial",
    "finance": "financial",
    "money": "financial",
    "edu": "education",
    "education": "education",
    "school": "education",
    "housing": "housing",
    "home": "housing",
    "house": "housing",
    "disability": "disability_equipment",
    "disability_equipment": "disability_equipment",
    "equipment": "disability_equipment",
    "nan": "unknown",
    "none": "unknown",
    "": "unknown"
}

# تطبيق التصحيح
df["assistance_type"] = df["assistance_type"].replace(mapping)

# %%
valid = [
    "medical",
    "food",
    "financial",
    "education",
    "housing",
    "disability_equipment",
    "unknown"
]

df["assistance_type"] = df["assistance_type"].apply(
    lambda x: x if x in valid else "unknown"
)

# %%
# df = pd.get_dummies(df, columns=["assistance_type"], prefix="assist")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          60000 non-null  object
#  13  need_level               57005 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  expense_to_income_ratio  57127 non-null  float64
#  18  recommended_org          56972 non-null  object
#  19  gender                   56985 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(5), int64(3), object(13)
# memory usage: 9.6+ MB

# %%
df["need_level"].value_counts()
# Out:
# need_level
# Medium    30348
# High      15607
# Low       11050
# Name: count, dtype: int64

# %%
df["need_level"] = (
    df["need_level"]
    .astype(str)
    .str.strip()
    .str.lower()
)
# قاموس تصحيح الأخطاء
need_map = {
    "high": "high",
    "hig": "high",
    "h": "high",

    "medium": "medium",
    "med": "medium",
    "mid": "medium",
    "m": "medium",

    "low": "low",
    "loww": "low",
    "l": "low",

    "nan": "unknown",
    "none": "unknown",
    "": "unknown"
}

df["need_level"] = df["need_level"].replace(need_map)

# %%
valid_levels = ["high", "medium", "low", "unknown"]

df["need_level"] = df["need_level"].apply(
    lambda x: x if x in valid_levels else "unknown"
)

# %%
df["need_level"] = df["need_level"].str.capitalize()
# df = pd.get_dummies(df, columns=["need_level"], prefix="need")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          60000 non-null  object
#  13  need_level               60000 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  expense_to_income_ratio  57127 non-null  float64
#  18  recommended_org          56972 non-null  object
#  19  gender                   56985 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(5), int64(3), object(13)
# memory usage: 9.6+ MB

# %%
df
# Out:
#                     name     national_id   case_type  family_size       phone  \
# 0        نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1               حسن كمال  65150394917789       ايتام            4  1014613636
# 2        فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3        ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4              غير معروف  63352487361031  اسره فقيره            7  1529047284
# ...                  ...             ...         ...          ...         ...
# 59995      علي عبدالرحمن      invalid_id       ايتام            3  1129841384
# 59996     خالد عبدالباقي  95920115758852       ايتام            7  1226110905
# 59997          صفاء شريف  28948804346961   ذوي اعاقه            3  1066819332
# 59998  ابراهيم عبدالفتاح  92279688670624   غير معروف            7  1122038189
# 59999       سعاد عبدالله  48171696267584  اسره فقيره            3  1062221585
#
#        amount_received  income_monthly  monthly_expenses    debts  \
# 0                200.0           17980             30500      0.0
# 1               1000.0           34970             63280   8961.0
# 2               1500.0           24820             44650      0.0
# 3                600.0           28730             55160      0.0
# 4               1500.0           31010             62080  10983.0
# ...                ...             ...               ...      ...
# 59995            500.0           30210             46680    960.0
# 59996            500.0           14570             31160      0.0
# 59997           2000.0           35180             71410      0.0
# 59998            800.0           15010             19620      0.0
# 59999            800.0           27380             53090  12583.0
#
#           housing_type  ...  \
# 0      سكن لدى الأقارب  ...
# 1                تمليك  ...
# 2      سكن لدى الأقارب  ...
# 3                تمليك  ...
# 4                تمليك  ...
# ...                ...  ...
# 59995       سكن عشوائي  ...
# 59996            إيجار  ...
# 59997       سكن عشوائي  ...
# 59998            إيجار  ...
# 59999            تمليك  ...
#
#                                             request_text  \
# 0      نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1      حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2      فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3      إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4      آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# ...                                                  ...
# 59995  علي عبدالرحمن من أيتام مقيم في مدينة نصر ويحتا...
# 59996  خالد عبدالباقي من أيتام مقيم في فيصل ويحتاج: ت...
# 59997  صفاء شريف من ذوي إعاقة مقيم في إمبابة ويحتاج: ...
# 59998  إبراهيم عبدالفتاح من أرملة مقيم في السيدة زينب...
# 59999  سعاد عبدالله من أسرة فقيرة مقيم في شبرا ويحتاج...
#
#             assistance_type need_level        city neighborhood  \
# 0      disability_equipment        Low    الزقازيق       إمبابة
# 1                      food       High       سوهاج        الهرم
# 2                 education        Low      الجيزة     العطارين
# 3                 financial     Medium  الإسكندرية        الهرم
# 4                      food       High    الزقازيق  السيدة زينب
# ...                     ...        ...         ...          ...
# 59995             financial     Medium       أسوان  السيدة زينب
# 59996                  food     Medium    بني سويف  سان ستيفانو
# 59997  disability_equipment     Medium         قنا    مدينة نصر
# 59998                  food        Low       أسوان         شبرا
# 59999                  food       High     القاهرة        الهرم
#
#       number_of_children  expense_to_income_ratio          recommended_org  \
# 0                    1.0                     1.70           جمعية الأورمان
# 1                    0.0                     1.81  جمعية التكافل الاجتماعي
# 2                    3.0                     1.55              جمعية رسالة
# 3                    1.0                     1.92                      NaN
# 4                    3.0                     2.00           جمعية الأورمان
# ...                  ...                      ...                      ...
# 59995                3.0                     1.54  جمعية التكافل الاجتماعي
# 59996                4.0                      NaN                      NaN
# 59997                NaN                     2.03          مؤسسة مصر الخير
# 59998                2.0                     1.31              جمعية رسالة
# 59999                3.0                     1.94              جمعية رسالة
#
#        gender debt_to_income_ratio
# 0      female             0.000000
# 1        male             0.256248
# 2      female             0.000000
# 3         NaN             0.000000
# 4      female             0.354176
# ...       ...                  ...
# 59995    male             0.031778
# 59996    male             0.000000
# 59997  female             0.000000
# 59998  female             0.000000
# 59999  female             0.459569
#
# [60000 rows x 21 columns]

# %%
# df.drop(columns=["assist_education","assist_financial","assist_food","assist_housing","assist_medical","assist_unknown","need_High","need_Low","need_Medium","need_Unknown"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          60000 non-null  object
#  13  need_level               60000 non-null  object
#  14  city                     57069 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       56954 non-null  float64
#  17  expense_to_income_ratio  57127 non-null  float64
#  18  recommended_org          56972 non-null  object
#  19  gender                   56985 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(5), int64(3), object(13)
# memory usage: 9.6+ MB

# %%
df["city"].value_counts()
# Out:
# city
# المنصورة      4160
# الإسكندرية    4156
# القاهرة       4119
# بني سويف      4115
# دمياط         4108
# بورسعيد       4097
# طنطا          4095
# أسيوط         4089
# المنيا        4087
# الجيزة        4061
# أسوان         4055
# سوهاج         4004
# الزقازيق      3972
# قنا           3951
# Name: count, dtype: int64

# %%
import pandas as pd

# 1) إصلاح الـ NaN المزيفة اللي اتقلبت لنص "nan"
df["city"] = df["city"].replace("nan", pd.NA)

# 2) تنسيق النصوص
df["city"] = (
    df["city"]
    .astype(str)
    .str.strip()
)

# 3) تحويل أي قيم غير معروفة → NaN
df["city"] = df["city"].replace({
    "nan": pd.NA,
    "None": pd.NA,
    "": pd.NA,
    "-": pd.NA,
})

# 4) توحيد أسماء المدن
city_map = {
    "المنصورة": "المنصورة",
    "الإسكندرية": "الإسكندرية",
    "القاهرة": "القاهرة",
    "بني سويف": "بني سويف",
    "دمياط": "دمياط",
    "بورسعيد": "بورسعيد",
    "طنطا": "طنطا",
    "أسيوط": "أسيوط",
    "المنيا": "المنيا",
    "الجيزة": "الجيزة",
    "أسوان": "أسوان",
    "سوهاج": "سوهاج",
    "الزقازيق": "الزقازيق",
    "قنا": "قنا",
}

df["city"] = df["city"].replace(city_map)

# 5) ملء القيم الناقصة بأشهر مدينة في الداتا
most_common_city = df["city"].mode()[0]
df["city"] = df["city"].fillna(most_common_city)

df["city"].value_counts()
# Out:
# city
# المنصورة      7091
# الإسكندرية    4156
# القاهرة       4119
# بني سويف      4115
# دمياط         4108
# بورسعيد       4097
# طنطا          4095
# أسيوط         4089
# المنيا        4087
# الجيزة        4061
# أسوان         4055
# سوهاج         4004
# الزقازيق      3972
# قنا           3951
# Name: count, dtype: int64

# %%
# التعامل مع القيم المفقودة
df["number_of_children"] = df["number_of_children"].fillna(0)  # لو عايزة صفر بدل NaN
df["number_of_children"] = df["number_of_children"].astype(int)

# %%
# تنظيف العمود وتحويل القيم المفقودة ل0
df["expense_to_income_ratio"] = df["expense_to_income_ratio"].fillna(0)

# %%
df["recommended_org"].value_counts()
# Out:
# recommended_org
# مؤسسة مصر الخير            11443
# جمعية الأورمان             11439
# جمعية التكافل الاجتماعي    11391
# جمعية رسالة                11384
# جمعية الباقيات الصالحات    11315
# Name: count, dtype: int64

# %%
# تحويل العمود لأي قيمة نص
df["recommended_org"] = df["recommended_org"].astype(str).str.strip()

# توحيد الحروف (اختياري)
df["recommended_org"] = df["recommended_org"].str.title()

# تحويل القيم الفارغة أو الغريبة لـ "غير معروف"
df["recommended_org"] = df["recommended_org"].replace({
    "Nan": "غير معروف",
    "None": "غير معروف",
    "Non": "غير معروف",
    "": "غير معروف"
})

# Optional: توحيد أي أخطاء شائعة في كتابة أسماء الجمعيات
org_map = {
    "مؤسسة مصر الخير": "مؤسسة مصر الخير",
    "جمعية الأورمان": "جمعية الأورمان",
    "جمعية التكافل الاجتماعي": "جمعية التكافل الاجتماعي",
    "جمعية رسالة": "جمعية رسالة",
    "جمعية الباقيات الصالحات": "جمعية الباقيات الصالحات"
}

df["recommended_org"] = df["recommended_org"].replace(org_map)

# %%
df["gender"].value_counts()
# Out:
# gender
# female    34193
# male      22792
# Name: count, dtype: int64

# %%
# تحويل النصوص لصيغة موحدة
df["gender"] = (
    df["gender"]
    .astype(str)          # تحويل أي قيمة لنص
    .str.strip()          # إزالة المسافات من البداية والنهاية
    .str.lower()          # تحويل كل الحروف لصغيرة
)

# تصحيح الأخطاء الإملائية الشائعة
gender_map = {
    "female": "Female",
    "femal": "Female",
    "f": "Female",
    "male": "Male",
    "ml": "Male",
    "m": "Male",
    "nan": "غير معروف",
    "none": "غير معروف",
    "": "غير معروف"
}

df["gender"] = df["gender"].replace(gender_map)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          60000 non-null  object
#  13  need_level               60000 non-null  object
#  14  city                     60000 non-null  object
#  15  neighborhood             57038 non-null  object
#  16  number_of_children       60000 non-null  int64
#  17  expense_to_income_ratio  60000 non-null  float64
#  18  recommended_org          60000 non-null  object
#  19  gender                   60000 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(4), int64(4), object(13)
# memory usage: 9.6+ MB

# %%
df["neighborhood"].value_counts()
# Out:
# neighborhood
# عين شمس          4473
# فيصل             4421
# حلوان            4420
# العطارين         4418
# سان ستيفانو      4410
# الهرم            4401
# المطرية          4401
# إمبابة           4400
# مدينة نصر        4368
# المعادي          4347
# المحلة الكبرى    4345
# شبرا             4330
# السيدة زينب      4304
# Name: count, dtype: int64

# %%
import pandas as pd

# 1) إعادة NaN الحقيقي لو اتقلب "nan" نص
df["neighborhood"] = df["neighborhood"].replace("nan", pd.NA)

# 2) تنسيق النصوص
df["neighborhood"] = (
    df["neighborhood"]
    .astype(str)
    .str.strip()
)

# 3) التعامل مع القيم غير المعروفة
df["neighborhood"] = df["neighborhood"].replace({
    "nan": pd.NA,
    "None": pd.NA,
    "": pd.NA,
    "-": pd.NA,
})

# 4) توحيد الأسماء
neighborhood_map = {
    "امبابة": "إمبابة",
    "إمبابة": "إمبابة",
    "الهرم": "الهرم",
    "العطارين": "العطارين",
    "السيدة زينب": "السيدة زينب",
    "فيصل": "فيصل",
    "عين شمس": "عين شمس",
    "المعادي": "المعادي",
    "مدينة نصر": "مدينة نصر",
    "المحلة الكبرى": "المحلة الكبرى",
    "سان ستيفانو": "سان ستيفانو",
}

df["neighborhood"] = df["neighborhood"].replace(neighborhood_map)

# 5) إكمال القيم المفقودة بأكثر حي شائع
most_common = df["neighborhood"].mode()[0]
df["neighborhood"] = df["neighborhood"].fillna(most_common)

df["neighborhood"].value_counts()
# Out:
# neighborhood
# عين شمس          7435
# فيصل             4421
# حلوان            4420
# العطارين         4418
# سان ستيفانو      4410
# الهرم            4401
# المطرية          4401
# إمبابة           4400
# مدينة نصر        4368
# المعادي          4347
# المحلة الكبرى    4345
# شبرا             4330
# السيدة زينب      4304
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     60000 non-null  object
#  1   national_id              60000 non-null  object
#  2   case_type                60000 non-null  object
#  3   family_size              60000 non-null  int64
#  4   phone                    60000 non-null  object
#  5   amount_received          60000 non-null  float64
#  6   income_monthly           60000 non-null  int64
#  7   monthly_expenses         60000 non-null  int64
#  8   debts                    60000 non-null  float64
#  9   housing_type             60000 non-null  object
#  10  health_status            60000 non-null  object
#  11  request_text             60000 non-null  object
#  12  assistance_type          60000 non-null  object
#  13  need_level               60000 non-null  object
#  14  city                     60000 non-null  object
#  15  neighborhood             60000 non-null  object
#  16  number_of_children       60000 non-null  int64
#  17  expense_to_income_ratio  60000 non-null  float64
#  18  recommended_org          60000 non-null  object
#  19  gender                   60000 non-null  object
#  20  debt_to_income_ratio     60000 non-null  float64
# dtypes: float64(4), int64(4), object(13)
# memory usage: 9.6+ MB

# %%
df.isna().sum()
# Out:
# name                       0
# national_id                0
# case_type                  0
# family_size                0
# phone                      0
# amount_received            0
# income_monthly             0
# monthly_expenses           0
# debts                      0
# housing_type               0
# health_status              0
# request_text               0
# assistance_type            0
# need_level                 0
# city                       0
# neighborhood               0
# number_of_children         0
# expense_to_income_ratio    0
# recommended_org            0
# gender                     0
# debt_to_income_ratio       0
# dtype: int64

# %%
df.head(20)
# Out:
#                name     national_id   case_type  family_size       phone  \
# 0   نجلاء عبدالباسط  50370498039207   ذوي اعاقه            3  1183629898
# 1          حسن كمال  65150394917789       ايتام            4  1014613636
# 2   فاطمة عبدالرحمن  32515235878793       ارمله            8  1013124808
# 3   ابراهيم الهواري  46071550347522       ايتام            6  1200902016
# 4         غير معروف  63352487361031  اسره فقيره            7  1529047284
# 5         امال انور  89658472227676       ارمله            2  1010017824
# 6     نجلاء عبدالله  51253738857239  اسره فقيره            2  1553270901
# 7       مراد النجار  95445940865922   ذوي اعاقه            8  1147055689
# 8        محمود انور  85678021986931       ايتام            3  1100123185
# 9       صفاء النجار  23198139775396   ذوي اعاقه            8  1546434338
# 10         علي مراد  40303468423610       ارمله            7  1032755810
# 11       محمود سليم  36102411705718  اسره فقيره            8  1133402148
# 12  امينة عبدالباسط  51519304333141       ايتام            3  1019702166
# 13      علي عبدالله  12333086288631   مريض مزمن            5  1570588449
# 14   مراد عبدالرحمن  67321016798224       ايتام            4  1155751227
# 15    علي عبدالباسط  46978018111616  اسره فقيره            6  1596678143
# 16  اسماء عبدالباسط      invalid_id       ايتام            5  1078280807
# 17  مصطفى عبدالباقي  58471964965744       ايتام            7  1124578465
# 18        سليم يوسف  10083506731202  اسره فقيره            2  1018629106
# 19       اسماء سليم  85776895049789       ارمله            3  1184941278
#
#     amount_received  income_monthly  monthly_expenses     debts  \
# 0             200.0           17980             30500      0.00
# 1            1000.0           34970             63280   8961.00
# 2            1500.0           24820             44650      0.00
# 3             600.0           28730             55160      0.00
# 4            1500.0           31010             62080  10983.00
# 5             800.0           25300             52430  14473.00
# 6             600.0           20070             46430      0.00
# 7               0.0           24990             44520   3034.00
# 8            1000.0           29810             68480     35.00
# 9             300.0           31840             49380      0.00
# 10            300.0           29270             40000      0.00
# 11           2000.0           35190             44650      0.00
# 12           1000.0           12730             17100  16047.00
# 13           2000.0           31200             58480   8541.00
# 14            800.0           25680             56450      0.00
# 15            200.0           28870             42270      0.00
# 16           2000.0           18150             39510      0.00
# 17           1000.0           24800             43070      0.00
# 18            800.0           32510             50160  11737.00
# 19            500.0            7100             17250  27561.07
#
#        housing_type  ...                                       request_text  \
# 0   سكن لدى الأقارب  ...  نجلاء عبدالباسط من ذوي إعاقة مقيم في المطرية و...
# 1             تمليك  ...  حسن كمال من أيتام مقيم في إمبابة ويحتاج: تحتاج...
# 2   سكن لدى الأقارب  ...  فاطمة عبدالرحمن من أرملة مقيم في سان ستيفانو و...
# 3             تمليك  ...  إبراهيم الهواري من أيتام مقيم في العطارين ويحت...
# 4             تمليك  ...  آمال النجار من أسرة فقيرة مقيم في المحلة الكبر...
# 5         سكن حكومي  ...  آمال أنور من أرملة مقيم في مدينة نصر ويحتاج: ت...
# 6             إيجار  ...  نجلاء عبدالله من أسرة فقيرة مقيم في المحلة الك...
# 7             تمليك  ...  مراد النجار من ذوي إعاقة مقيم في العطارين ويحت...
# 8        سكن عشوائي  ...  محمود أنور من أيتام مقيم في حلوان ويحتاج: تحتا...
# 9             تمليك  ...  صفاء النجار من ذوي إعاقة مقيم في شبرا ويحتاج: ...
# 10            إيجار  ...  علي مراد من أرملة مقيم في سان ستيفانو ويحتاج: ...
# 11            إيجار  ...  محمود سليم من أسرة فقيرة مقيم في مدينة نصر ويح...
# 12        سكن حكومي  ...  أمينة عبدالباسط من أيتام مقيم في الهرم ويحتاج:...
# 13            تمليك  ...  علي عبدالله من مريض مزمن مقيم في إمبابة ويحتاج...
# 14            تمليك  ...  مراد عبدالرحمن من أيتام مقيم في إمبابة ويحتاج:...
# 15       سكن عشوائي  ...  علي عبدالباسط من أسرة فقيرة مقيم في مدينة نصر ...
# 16  سكن لدى الأقارب  ...  أسماء عبدالباسط من أيتام مقيم في شبرا ويحتاج: ...
# 17            إيجار  ...  مصطفى عبدالباقي من أيتام مقيم في الهرم ويحتاج:...
# 18            تمليك  ...  سليم يوسف من أسرة فقيرة مقيم في مدينة نصر ويحت...
# 19            تمليك  ...  أسماء سليم من أرملة مقيم في السيدة زينب ويحتاج...
#
#          assistance_type need_level        city   neighborhood  \
# 0   disability_equipment        Low    الزقازيق         إمبابة
# 1                   food       High       سوهاج          الهرم
# 2              education        Low      الجيزة       العطارين
# 3              financial     Medium  الإسكندرية          الهرم
# 4                   food       High    الزقازيق    السيدة زينب
# 5                   food       High      الجيزة         إمبابة
# 6              financial     Medium      الجيزة           فيصل
# 7                medical     Medium    بني سويف        عين شمس
# 8                   food       High    الزقازيق        عين شمس
# 9   disability_equipment    Unknown        طنطا        المعادي
# 10                  food        Low  الإسكندرية        عين شمس
# 11                  food    Unknown      المنيا      مدينة نصر
# 12             education     Medium      الجيزة  المحلة الكبرى
# 13               unknown       High        طنطا    سان ستيفانو
# 14                  food     Medium  الإسكندرية    سان ستيفانو
# 15               unknown        Low      الجيزة    السيدة زينب
# 16               unknown     Medium     بورسعيد          حلوان
# 17               unknown     Medium        طنطا        المطرية
# 18                  food       High       سوهاج           شبرا
# 19             financial       High     بورسعيد          حلوان
#
#    number_of_children  expense_to_income_ratio          recommended_org  \
# 0                   1                     1.70           جمعية الأورمان
# 1                   0                     1.81  جمعية التكافل الاجتماعي
# 2                   3                     1.55              جمعية رسالة
# 3                   1                     1.92                غير معروف
# 4                   3                     2.00           جمعية الأورمان
# 5                   1                     2.07                غير معروف
# 6                   2                     2.31           جمعية الأورمان
# 7                   0                     1.82           جمعية الأورمان
# 8                   2                     2.30  جمعية الباقيات الصالحات
# 9                   2                     1.55  جمعية التكافل الاجتماعي
# 10                  0                     1.37          مؤسسة مصر الخير
# 11                  5                     2.14              جمعية رسالة
# 12                  3                     1.34  جمعية التكافل الاجتماعي
# 13                  1                     1.87  جمعية التكافل الاجتماعي
# 14                  2                     2.20              جمعية رسالة
# 15                  0                     1.46  جمعية الباقيات الصالحات
# 16                  6                     2.18  جمعية الباقيات الصالحات
# 17                  4                     1.74                غير معروف
# 18                  1                     1.54              جمعية رسالة
# 19                  3                     2.43  جمعية الباقيات الصالحات
#
#        gender debt_to_income_ratio
# 0      Female             0.000000
# 1        Male             0.256248
# 2      Female             0.000000
# 3   غير معروف             0.000000
# 4      Female             0.354176
# 5      Female             0.572055
# 6      Female             0.000000
# 7        Male             0.121409
# 8        Male             0.001174
# 9      Female             0.000000
# 10     Female             0.000000
# 11       Male             0.000000
# 12     Female             1.260566
# 13       Male             0.273750
# 14       Male             0.000000
# 15       Male             0.000000
# 16     Female             0.000000
# 17       Male             0.000000
# 18       Male             0.361027
# 19     Female             3.881841
#
# [20 rows x 21 columns]

# %%
# حفظ الداتا المنضفة في ملف Excel
df.to_excel("Awnn_cleaned_data.xlsx", index=False)
